# %% [markdown]
# # TRAFFIC SIGN RECOGNITION SYSTEM

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Make the plots bigger by default and setting the default line width

# %%
plt.rcParams["figure.figsize"] = (16,10) #Make the plots bigger by default
plt.rcParams["lines.linewidth"] = 2 #Setting the default line width
plt.style.use("ggplot")

# %%
data_dir = 'C:\\Users\\Abhishek Mishra\\Desktop\\Minor project final\\Data'
train_path = 'C:\\Users\\Abhishek Mishra\\Desktop\\Minor project final\\Data\\Train'
test_path = 'C:\\Users\\Abhishek Mishra\\Desktop\\Minor project final\\Data\\Test'
IMG_HEIGHT = 30
IMG_WIDTH = 30

# %% [markdown]
# # Number of Classes

# %%
NUM_CATEGORIES = len(os.listdir(train_path))
NUM_CATEGORIES
# Out:
# 43

# %% [markdown]
# # Visualizing all the different Signs

# %%
import pathlib

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, array_to_img, load_img

# %%
img_dir = pathlib.Path(train_path)
plt.figure(figsize=(100,100))
index = 0
for i in range(NUM_CATEGORIES):
    plt.subplot(9, 9, i+1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    sign = list(img_dir.glob(f'{i}/*'))[0]
    img = load_img(sign, target_size=(IMG_WIDTH, IMG_HEIGHT))
    plt.imshow(img)
plt.show()

# %% [markdown]
# # Label Overview

# %%
classes = { 0:'Speed limit (20km/h)',
            1:'Speed limit (30km/h)', 
            2:'Speed limit (50km/h)', 
            3:'Speed limit (60km/h)', 
            4:'Speed limit (70km/h)', 
            5:'Speed limit (80km/h)', 
            6:'End of speed limit (80km/h)', 
            7:'Speed limit (100km/h)', 
            8:'Speed limit (120km/h)', 
            9:'No passing', 
            10:'No passing veh over 3.5 tons', 
            11:'Right-of-way at intersection', 
            12:'Priority road', 
            13:'Yield', 
            14:'Stop', 
            15:'No vehicles', 
            16:'Veh > 3.5 tons prohibited', 
            17:'No entry', 
            18:'General caution', 
            19:'Dangerous curve left', 
            20:'Dangerous curve right', 
            21:'Double curve', 
            22:'Bumpy road', 
            23:'Slippery road', 
            24:'Road narrows on the right', 
            25:'Road work', 
            26:'Traffic signals', 
            27:'Pedestrians', 
            28:'Children crossing', 
            29:'Bicycles crossing', 
            30:'Beware of ice/snow',
            31:'Wild animals crossing', 
            32:'End speed + passing limits', 
            33:'Turn right ahead', 
            34:'Turn left ahead', 
            35:'Ahead only', 
            36:'Go straight or right', 
            37:'Go straight or left', 
            38:'Keep right', 
            39:'Keep left', 
            40:'Roundabout mandatory', 
            41:'End of no passing', 
            42:'End no passing veh > 3.5 tons' }

# %% [markdown]
# # Plotting Graph for showing the number of images in each class

# %%
import numpy as np

# %%
folders = os.listdir(train_path)


train_number = []
class_num = []

for folder in folders:
    train_files = os.listdir(train_path + '/' + folder)
    train_number.append(len(train_files))
    class_num.append(classes[int(folder)])



plt.figure(figsize=(21,10))  
plt.bar(class_num, train_number, color='green')
plt.xticks(class_num, rotation='vertical',color='red')
plt.show()

# %% [markdown]
# # Converting lists into numpy arrays

# %%
def load_data(data_dir):
    images = list()
    labels = list()
    for category in range(NUM_CATEGORIES):
        categories = os.path.join(data_dir, str(category))
        for img in os.listdir(categories):
            img = load_img(os.path.join(categories, img), target_size=(30, 30))
            image = img_to_array(img)
            images.append(image)
            labels.append(category)
    
    return images, labels

# %%
images, labels = load_data(train_path)

# %%
from tensorflow.keras.utils import to_categorical

# %%
labels = to_categorical(labels)

# %% [markdown]
# # Splitting training and testing dataset

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(np.array(images), labels, test_size=0.3)

# %%
x_train/=255
x_test/=255

# %%
print('x_train shape:',x_train.shape)
# Out:
# x_train shape: (27446, 30, 30, 3)

# %%
print('Number of Signs in x_train',x_train.shape[0])
# Out:
# Number of Signs in x_train 27446

# %%
print('Number of Signs in x_test',x_test.shape[0])
# Out:
# Number of Signs in x_test 11763

# %%
print('x_test shape:',x_test.shape)
# Out:
# x_test shape: (11763, 30, 30, 3)

# %%
input_shape=( 30, 30, 3)

# %% [markdown]
# # Building the model

# %%
from keras.models import Sequential

# %%
model = Sequential()

# %%
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, MaxPooling2D

# %%
# First Convolutional Layer
model.add(Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=input_shape))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))

# %%
# Second Convolutional Layer
model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))

# %%
# Third Convolutional Layer
model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))

model.add(Flatten())
model.add(Dense(units=64, activation='relu'))
model.add(Dense(NUM_CATEGORIES, activation='softmax'))

# %% [markdown]
# # Compiling the model

# %%
lr = 0.001
epochs = 30
model.compile(loss='categorical_crossentropy',optimizer="adam",metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  dense_1 (Dense)             (None, 43)                2795
#
# =================================================================
# Total params: 124,715
# Trainable params: 124,715
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train,validation_split=0.3,epochs=20)
# Out:
# Epoch 1/20
# 601/601 [==============================] - 23s 36ms/step - loss: 1.7801 - accuracy: 0.5019 - val_loss: 0.5638 - val_accuracy: 0.8285
# Epoch 2/20
# 601/601 [==============================] - 16s 26ms/step - loss: 0.4611 - accuracy: 0.8589 - val_loss: 0.2906 - val_accuracy: 0.9215
# Epoch 3/20
# 601/601 [==============================] - 13s 22ms/step - loss: 0.2796 - accuracy: 0.9145 - val_loss: 0.1803 - val_accuracy: 0.9495
# Epoch 4/20
# 601/601 [==============================] - 13s 22ms/step - loss: 0.2056 - accuracy: 0.9367 - val_loss: 0.1598 - val_accuracy: 0.9583
# Epoch 5/20
# 601/601 [==============================] - 13s 22ms/step - loss: 0.1605 - accuracy: 0.9489 - val_loss: 0.1338 - val_accuracy: 0.9603
# Epoch 6/20
# 601/601 [==============================] - 13s 22ms/step - loss: 0.1372 - accuracy: 0.9558 - val_loss: 0.0881 - val_accuracy: 0.9763
# Epoch 7/20
# 601/601 [==============================] - 13s 22ms/step - loss: 0.1116 - accuracy: 0.9641 - val_loss: 0.0970 - val_accuracy: 0.9750
# Epoch 8/20
# 601/601 [==============================] - 14s 23ms/step - loss: 0.1057 - accuracy: 0.9652 - val_loss: 0.0843 - val_accuracy: 0.9787
# Epoch 9/20
# 601/601 [==============================] - 14s 23ms/step - loss: 0.0874 - accuracy: 0.9705 - val_loss: 0.0856 - val_accuracy: 0.9785
# Epoch 10/20
# 601/601 [==============================] - 13s 22ms/step - loss: 0.0789 - accuracy: 0.9732 - val_loss: 0.0763 - val_accuracy: 0.9797
# Epoch 11/20
# 601/601 [==============================] - 13s 22ms/step - loss: 0.0703 - accuracy: 0.9752 - val_loss: 0.0726 - val_accuracy: 0.9809
# Epoch 12/20
# 601/601 [==============================] - 13s 22ms/step - loss: 0.0660 - accuracy: 0.9783 - val_loss: 0.0705 - val_accuracy: 0.9824
# Epoch 13/20
# 601/601 [==============================] - 13s 22ms/step - loss: 0.0674 - accuracy: 0.9780 - val_loss: 0.0677 - val_accuracy: 0.9840
# Epoch 14/20
# 601/601 [==============================] - 13s 22ms/step - loss: 0.0593 - accuracy: 0.9793 - val_loss: 0.0659 - val_accuracy: 0.9836
# Epoch 15/20
# 601/601 [==============================] - 14s 23ms/step - loss: 0.0548 - accuracy: 0.9822 - val_loss: 0.0633 - val_accuracy: 0.9834
# Epoch 16/20
# 601/601 [==============================] - 15s 26ms/step - loss: 0.0515 - accuracy: 0.9829 - val_loss: 0.0603 - val_accuracy: 0.9847
# Epoch 17/20
# 601/601 [==============================] - 15s 25ms/step - loss: 0.0516 - accuracy: 0.9825 - val_loss: 0.0538 - val_accuracy: 0.9870
# Epoch 18/20
# 601/601 [==============================] - 14s 24ms/step - loss: 0.0477 - accuracy: 0.9839 - val_loss: 0.0765 - val_accuracy: 0.9814
# Epoch 19/20
# 601/601 [==============================] - 14s 24ms/step - loss: 0.0513 - accuracy: 0.9838 - val_loss: 0.0578 - val_accuracy: 0.9845
# Epoch 20/20
# 601/601 [==============================] - 14s 24ms/step - loss: 0.0427 - accuracy: 0.9862 - val_loss: 0.0683 - val_accuracy: 0.9823

# %%
model.save('My_Signs_Model.h5')
print("Saving the bot as My_Signs_Model.h5")
# Out:
# Saving the bot as My_Signs_Model.h5

# %% [markdown]
# # Evaluate the model

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print('test set accuracy: ', accuracy * 100)
# Out:
# 368/368 [==============================] - 2s 6ms/step - loss: 0.0639 - accuracy: 0.9815
# test set accuracy:  98.14673066139221

# %% [markdown]
# # Plotting graphs for accuracy

# %%
plt.plot(history.history['accuracy'], color='green')
plt.plot(history.history['val_accuracy'], color='yellow')
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train accuracy', 'validation accuracy'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'], color='orange')
plt.plot(history.history['val_loss'], color='cyan')
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'validation loss'], loc='lower right')
plt.show()

# %% [markdown]
# # Testing accuracy and making predictions on Test data

# %%
for i in range(36):
    plt.subplot(6,6,i+1)
    plt.imshow(x_test[i])

# %%
#Predicting the correct sign
image_index=0
plt.imshow(x_test[image_index])
n = np.array(x_test[image_index])
print(n.size)
p = n.reshape(1, 30, 30, 3)
pred = classes[model.predict(p).argmax()]
print("The predicted image is {}".format(pred))
from sklearn.metrics import accuracy_score
print(accuracy)
# Out:
# 2700
# 1/1 [==============================] - 0s 114ms/step
# The predicted image is Speed limit (20km/h)
# 0.9814673066139221

# %%
import pyttsx3
engineio=pyttsx3.init()
engineio.say(pred)
engineio.runAndWait()

# %%
model.save('Traffic_Sign_Classifier.h5')

# %%
pip install pyttsx3
# Out:
# Requirement already satisfied: pyttsx3 in c:\users\abhishek mishra\anaconda3\lib\site-packages (2.90)
# Requirement already satisfied: pywin32 in c:\users\abhishek mishra\anaconda3\lib\site-packages (from pyttsx3) (302)
# Requirement already satisfied: pypiwin32 in c:\users\abhishek mishra\anaconda3\lib\site-packages (from pyttsx3) (223)
# Requirement already satisfied: comtypes in c:\users\abhishek mishra\anaconda3\lib\site-packages (from pyttsx3) (1.1.10)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Loading the Pre-trained model for classify the Sign

# %%
import tkinter as tk
from tkinter import filedialog
from tkinter import *
from PIL import ImageTk, Image
import numpy 
import cv2
import pyttsx3
#load the trained model to classify sign
from keras.models import load_model
model = load_model('Traffic_Sign_Classifier.h5')

# %% [markdown]
# # Dictionary to label all traffic signs class.

# %%
classes = { 1:'Speed limit (20km/h)',
            2:'Speed limit (30km/h)', 
            3:'Speed limit (50km/h)', 
            4:'Speed limit (60km/h)', 
            5:'Speed limit (70km/h)', 
            6:'Speed limit (80km/h)', 
            7:'End of speed limit (80km/h)', 
            8:'Speed limit (100km/h)', 
            9:'Speed limit (120km/h)', 
            10:'No passing', 
            11:'No passing veh over 3.5 tons', 
            12:'Right-of-way at intersection', 
            13:'Priority road', 
            14:'Yield', 
            15:'Stop', 
            16:'No vehicles', 
            17:'Veh > 3.5 tons prohibited', 
            18:'No entry', 
            19:'General caution', 
            20:'Dangerous curve left', 
            21:'Dangerous curve right', 
            22:'Double curve', 
            23:'Bumpy road', 
            24:'Slippery road', 
            25:'Road narrows on the right', 
            26:'Road work', 
            27:'Traffic signals', 
            28:'Pedestrians', 
            29:'Children crossing', 
            30:'Bicycles crossing', 
            31:'Beware of ice/snow',
            32:'Wild animals crossing', 
            33:'End speed + passing limits', 
            34:'Turn right ahead', 
            35:'Turn left ahead', 
            36:'Ahead only', 
            37:'Go straight or right', 
            38:'Go straight or left', 
            39:'Keep right', 
            40:'Keep left', 
            41:'Roundabout mandatory', 
            42:'End of no passing', 
            43:'End no passing veh > 3.5 tons' }

# %% [markdown]
# # Initialise GUI

# %%
top=tk.Tk()
top.geometry('900x700')
top.title('Traffic sign classification')
abhishek=Image.open("C:\\Users\\Abhishek Mishra\\Desktop\\Minor project final\\knopka-ivy-jocViE_c8R0-unsplash.jpg")
Traffic_abhishek=ImageTk.PhotoImage(abhishek)
heading1=Label(top,image=Traffic_abhishek,height=1080,width=1920)
heading1.place(x=0,y=0)
top.configure(background='#2F4F4F')
label=Label(top,background='red', font=('georgia',15,'bold'))
sign_image = Label(top)

# %%
def classify(test_path):
    global label_packed
    image = Image.open(test_path)
    image = image.resize((30,30))
    image = numpy.expand_dims(image, axis=0)
    image = numpy.array(image)
    pred=numpy.argmax(model.predict([image])[0], axis=-1)
    sign=classes[pred+1]
    print(sign)
    engineio=pyttsx3.init()
    engineio.say(sign)
    engineio.runAndWait()
    label.configure(foreground='#FFC0CB', text=sign)

# %%
def show_classify_button(test_path):
    classify_b=Button(top,text="Recognize \n the \n Sign?",command=lambda: classify(test_path),padx=10,pady=10)
    classify_b.configure(background='#97FFFF', foreground='darksalmon',font=('georgia',15,'bold'))
    classify_b.place(relx=0.79,rely=0.46)

# %%
FIRST=Image.open("C:\\Users\\Abhishek Mishra\\Desktop\\Minor project final\\image of TSR.jpg")
Traffic_abhishek=ImageTk.PhotoImage(FIRST)
def Camera_button_new_window():
    cam_root=Toplevel()
    cam_root.geometry('900x700')
    cam_root.title('Real Time Traffic Sign Classification')
    heading2=Label(cam_root,image=Traffic_abhishek1,height=899,width=990)
    heading2.place(x=0,y=0)
    cam_root.configure(background='#2F4F4F')
    label1=Label(cam_root,background='red', font=('georgia',15,'bold'))
    sign_image1 = Label(cam_root)
    real_time=Button(cam_root,text="Click \n for \n camera",command=open_camera,padx=10,pady=5)
    real_time.configure(background='lightpink', foreground='limegreen',font=('georgia',15,'bold'))
    real_time.place(x=400,y=400)
    heading3= Label(cam_root, text="Real Time Road Traffic Sign Recognition",pady=15, font=('georgia',15,'bold'))
    heading3.configure(background='crimson',foreground='#2F4F4F')
    heading3.pack(pady=60)

# %%
def open_camera():
    def readImage(train_path):
        img = cv2.imread(train_path+'/'+train_path,1)
        img = cv2.resize(img,(500,400))
        return img
    
    def returnRedness(img):
        yuv = cv2.cvtColor(img,cv2.COLOR_BGR2YUV)
        y, u, v = cv2.split(yuv)
        return v

    def threshold(img,T=150):
        _, img = cv2.threshold(img,T,255,cv2.THRESH_BINARY)
        return img 

    def findContour(img):
        contours, hierarchy = cv2.findContours(img, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        return contours

    def findBiggestContour(contours):
        m = 0
        c = [cv2.contourArea(i) for i in contours]
        return contours[c.index(max(c))]

    def boundaryBox(img,contours):
        x, y, w, h = cv2.boundingRect(contours)
        img = cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)
        sign = img[y:(y+h) , x:(x+w)]
        return img, sign

    def preprocessingImageToClassifier(image=None,imageSize=28,mu=89.77428691773054,std=70.85156431910688):
        image = cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
        image = cv2.resize(image,(imageSize,imageSize))
        image = (image - mu) / std
        image = image.reshape(1,imageSize,imageSize,1)
        return image

    def predict(sign):
        img = preprocessingImageToClassifier(sign,imageSize=28)
        return np.argmax(model.predict(img))

#--------------------------------------------------------------------------
    labelToText =  { 1:'Speed limit (20km/h)',
            2:'Speed limit (30km/h)', 
            3:'Speed limit (50km/h)', 
            4:'Speed limit (60km/h)', 
            5:'Speed limit (70km/h)', 
            6:'Speed limit (80km/h)', 
            7:'End of speed limit (80km/h)', 
            8:'Speed limit (100km/h)', 
            9:'Speed limit (120km/h)', 
            10:'No passing', 
            11:'No passing veh over 3.5 tons', 
            12:'Right-of-way at intersection', 
            13:'Priority road', 
            14:'Yield', 
            15:'Stop', 
            16:'No vehicles', 
            17:'Veh > 3.5 tons prohibited', 
            18:'No entry', 
            19:'General caution', 
            20:'Dangerous curve left', 
            21:'Dangerous curve right', 
            22:'Double curve', 
            23:'Bumpy road', 
            24:'Slippery road', 
            25:'Road narrows on the right', 
            26:'Road work', 
            27:'Traffic signals', 
            28:'Pedestrians', 
            29:'Children crossing', 
            30:'Bicycles crossing', 
            31:'Beware of ice/snow',
            32:'Wild animals crossing', 
            33:'End speed + passing limits', 
            34:'Turn right ahead', 
            35:'Turn left ahead', 
            36:'Ahead only', 
            37:'Go straight or right', 
            38:'Go straight or left', 
            39:'Keep right', 
            40:'Keep left', 
            41:'Roundabout mandatory', 
            42:'End of no passing'}
    cap=cv2.VideoCapture(0)
    while(True):
        _, frame = cap.read()
        redness = returnRedness(frame) # step 1 --> specify the redness of the image
        thresh = threshold(redness)
        try:
            contours = findContour(thresh)
            big = findBiggestContour(contours)
            if cv2.contourArea(big) > 3000:
                print(cv2.contourArea(big))
                img,sign = boundaryBox(frame,big)
                cv2.imshow('frame',img)
                print("Now,I see:",labelToText[predict(sign)])
            else:
                cv2.imshow('frame',frame)
               
        except:
            cv2.imshow('frame',frame)
            
        if cv2.waitKey(1) & 0xFF == ord('q') :
            break

    cap.release()
    cv2.destroyAllWindows()

# %%
def upload_image():
    try:
        test_path=filedialog.askopenfilename()
        uploaded=Image.open(test_path)
        uploaded.thumbnail(((top.winfo_width()/2.25),(top.winfo_height()/2.25)))
        im=ImageTk.PhotoImage(uploaded)
        sign_image.configure(image=im)
        sign_image.image=im
        label.configure(text='')
        show_classify_button(test_path)
    except:
        pass
upload=Button(top,text="Select a traffic sign",command=upload_image,padx=10,pady=5)
upload.configure(background='#97FFFF', foreground='darksalmon',font=('georgia',15,'bold'))
upload.pack(side=BOTTOM,pady=50)
sign_image.pack(side=BOTTOM,expand=True)
label.pack(side=BOTTOM,expand=True)
real_time=Button(top,text="Recognize \n the \n real \n time \n Traffic \n Sign \n by \n opening \n the \n camera?",command=Camera_button_new_window,padx=10,pady=5)
real_time.configure(background='#97FFFF', foreground='darksalmon',font=('georgia',15,'bold'))
real_time.place(x=90,y=300)

# %%
heading= Label(top, text="Road Traffic Sign Recognition",pady=30, font=('georgia',25,'bold'))
heading.configure(background='#2F4F4F',foreground='#FFD700')
heading.pack(pady=60)
top.mainloop()
# Out:
# 1/1 [==============================] - 0s 91ms/step
# Veh > 3.5 tons prohibited
# 1/1 [==============================] - 0s 32ms/step
# No vehicles
# 1/1 [==============================] - 0s 32ms/step
# Priority road
# 1/1 [==============================] - 0s 28ms/step
# Priority road
# 1/1 [==============================] - 0s 26ms/step
# General caution
# 1/1 [==============================] - 0s 27ms/step
# No passing
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Abhishek Mishra\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\Abhishek Mishra\AppData\Local\Temp\ipykernel_2764\4141819285.py", line 2, in <lambda>
#     classify_b=Button(top,text="Recognize \n the \n Sign?",command=lambda: classify(test_path),padx=10,pady=10)
#   File "C:\Users\Abhishek Mishra\AppData\Local\Temp\ipykernel_2764\64689653.py", line 7, in classify
#     pred=numpy.argmax(model.predict([image])[0], axis=-1)
#   File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py", line 52, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Graph execution error:
#
# Detected at node 'sequential/conv2d/Relu' defined at (most recent call last):
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#       app.launch_new_instance()
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#       app.start()
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
#       self.io_loop.start()
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 460, in process_one
#       await dispatch(*args)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 367, in dispatch_shell
#       await result
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 662, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 360, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 532, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2863, in run_cell
#       result = self._run_cell(
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2909, in _run_cell
#       return runner(coro)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3106, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3309, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3369, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\Abhishek Mishra\AppData\Local\Temp\ipykernel_2764\2786522825.py", line 4, in <cell line: 4>
#       top.mainloop()
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\tkinter\__init__.py", line 1429, in mainloop
#       self.tk.mainloop(n)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#       return self.func(*args)
#     File "C:\Users\Abhishek Mishra\AppData\Local\Temp\ipykernel_2764\4141819285.py", line 2, in <lambda>
#       classify_b=Button(top,text="Recognize \n the \n Sign?",command=lambda: classify(test_path),padx=10,pady=10)
#     File "C:\Users\Abhishek Mishra\AppData\Local\Temp\ipykernel_2764\64689653.py", line 7, in classify
#       pred=numpy.argmax(model.predict([image])[0], axis=-1)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\training.py", line 2350, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\training.py", line 2137, in predict_function
#       return step_function(self, iterator)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\training.py", line 2123, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\training.py", line 2111, in run_step
#       outputs = model.predict_step(data)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\training.py", line 2079, in predict_step
#       return self(x, training=False)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\training.py", line 561, in __call__
#       return super().__call__(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 1132, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\sequential.py", line 413, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\functional.py", line 511, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\functional.py", line 668, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 1132, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\layers\convolutional\base_conv.py", line 314, in call
#       return self.activation(outputs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\activations.py", line 317, in relu
#       return backend.relu(
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\backend.py", line 5369, in relu
#       x = tf.nn.relu(x)
# Node: 'sequential/conv2d/Relu'
# convolution input must be 4-dimensional: [1,30,30]
# 	 [[{{node sequential/conv2d/Relu}}]] [Op:__inference_predict_function_73749]
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Abhishek Mishra\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\Abhishek Mishra\AppData\Local\Temp\ipykernel_2764\4141819285.py", line 2, in <lambda>
#     classify_b=Button(top,text="Recognize \n the \n Sign?",command=lambda: classify(test_path),padx=10,pady=10)
#   File "C:\Users\Abhishek Mishra\AppData\Local\Temp\ipykernel_2764\64689653.py", line 7, in classify
#     pred=numpy.argmax(model.predict([image])[0], axis=-1)
#   File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py", line 52, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Graph execution error:
#
# Detected at node 'sequential/conv2d/Relu' defined at (most recent call last):
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#       app.launch_new_instance()
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#       app.start()
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
#       self.io_loop.start()
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 460, in process_one
#       await dispatch(*args)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 367, in dispatch_shell
#       await result
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 662, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 360, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 532, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2863, in run_cell
#       result = self._run_cell(
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2909, in _run_cell
#       return runner(coro)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3106, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3309, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3369, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\Abhishek Mishra\AppData\Local\Temp\ipykernel_2764\2786522825.py", line 4, in <cell line: 4>
#       top.mainloop()
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\tkinter\__init__.py", line 1429, in mainloop
#       self.tk.mainloop(n)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#       return self.func(*args)
#     File "C:\Users\Abhishek Mishra\AppData\Local\Temp\ipykernel_2764\4141819285.py", line 2, in <lambda>
#       classify_b=Button(top,text="Recognize \n the \n Sign?",command=lambda: classify(test_path),padx=10,pady=10)
#     File "C:\Users\Abhishek Mishra\AppData\Local\Temp\ipykernel_2764\64689653.py", line 7, in classify
#       pred=numpy.argmax(model.predict([image])[0], axis=-1)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\training.py", line 2350, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\training.py", line 2137, in predict_function
#       return step_function(self, iterator)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\training.py", line 2123, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\training.py", line 2111, in run_step
#       outputs = model.predict_step(data)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\training.py", line 2079, in predict_step
#       return self(x, training=False)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\training.py", line 561, in __call__
#       return super().__call__(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 1132, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\sequential.py", line 413, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\functional.py", line 511, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\functional.py", line 668, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 1132, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\layers\convolutional\base_conv.py", line 314, in call
#       return self.activation(outputs)
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\activations.py", line 317, in relu
#       return backend.relu(
#     File "C:\Users\Abhishek Mishra\anaconda3\lib\site-packages\keras\backend.py", line 5369, in relu
#       x = tf.nn.relu(x)
# Node: 'sequential/conv2d/Relu'
# convolution input must be 4-dimensional: [1,30,30]
# 	 [[{{node sequential/conv2d/Relu}}]] [Op:__inference_predict_function_73749]
# 1/1 [==============================] - 0s 41ms/step
# Keep right
# 1/1 [==============================] - 0s 20ms/step
# Keep right
# 1/1 [==============================] - 0s 20ms/step
# Keep right
# 1/1 [==============================] - 0s 22ms/step
# Priority road
# 1/1 [==============================] - 0s 43ms/step
# Priority road
# 1/1 [==============================] - 0s 43ms/step
# General caution
# 1/1 [==============================] - 0s 22ms/step
# Road work

# %% [markdown]
# ![Traffic1.JPG](attachment:Traffic1.JPG)

# %% [markdown]
# ![Traffic2.JPG](attachment:Traffic2.JPG)

# %% [markdown]
# ![Traffic5.JPG](attachment:Traffic5.JPG)

# %% [markdown]
# ![Traffic4.JPG](attachment:Traffic4.JPG)
# ![Traffic3.JPG](attachment:Traffic3.JPG)

# %% [markdown]
# # ..............................................THANK YOU :))))........................................
